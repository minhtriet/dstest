# %%
import glob
import json
import pandas as pd
from pathlib import Path

# %%
def create_dataset(dataset_path):
    data = []
    for filename in glob.glob(dataset_path):
        with open(filename) as f:
            annotate = json.load(f)
            for match in annotate['form']:
                match['file'] = Path(filename).stem
            data.extend(annotate['form'])
    return pd.DataFrame.from_records(data)

# %%
train_dataset = create_dataset("training_data/annotations/*.json")
test_dataset = create_dataset("testing_data/annotations/*.json")

# %%
train_dataset.to_csv("train_data.csv", index=False)
test_dataset.to_csv("test_data.csv", index=False)

# %%
data
# Out:
#                        box                                            text  \
# 0     [394, 145, 433, 162]                                           ITEM:
# 1     [109, 112, 151, 129]                                           DATE:
# 2     [110, 140, 159, 155]                                          BRAND:
# 3     [109, 183, 168, 198]                                         SUMMARY
# 4     [175, 184, 193, 195]                                              OF
# ...                    ...                                             ...
# 7406  [397, 881, 528, 914]  Topline w/o 12 /18 /95 Final Report 12/ 31/ 95
# 7407  [577, 742, 635, 759]                                        $100 600
# 7408  [398, 761, 560, 779]                          Revised Costs (if any)
# 7409  [397, 788, 532, 806]                             Fieldwork Schedule:
# 7410  [204, 642, 295, 659]                                  A & G Research
#
#          label                                              words     linking  \
# 0     question   [{'box': [394, 145, 433, 162], 'text': 'ITEM:'}]   [[0, 15]]
# 1     question   [{'box': [109, 112, 151, 129], 'text': 'DATE:'}]   [[1, 13]]
# 2     question  [{'box': [110, 140, 159, 155], 'text': 'BRAND:'}]   [[2, 14]]
# 3     question  [{'box': [109, 183, 168, 198], 'text': 'SUMMAR...          []
# 4     question      [{'box': [175, 184, 193, 195], 'text': 'OF'}]          []
# ...        ...                                                ...         ...
# 7406    answer  [{'text': 'Topline', 'box': [398, 883, 443, 89...  [[59, 60]]
# 7407     other  [{'text': '$100', 'box': [577, 742, 606, 757]}...          []
# 7408  question  [{'text': '', 'box': [398, 761, 409, 774]}, {'...          []
# 7409  question  [{'text': 'Fieldwork', 'box': [397, 788, 464, ...  [[63, 58]]
# 7410    answer  [{'text': 'A', 'box': [204, 642, 214, 657]}, {...  [[47, 64]]
#
#       id       file
# 0      0   71206427
# 1      1   71206427
# 2      2   71206427
# 3      3   71206427
# 4      4   71206427
# ...   ..        ...
# 7406  60  80310840a
# 7407  61  80310840a
# 7408  62  80310840a
# 7409  63  80310840a
# 7410  64  80310840a
#
# [7411 rows x 7 columns]

# %%
set(data['label'])
# Out:
# {'answer', 'header', 'other', 'question'}

# %%
data['label'].value_counts()
# Out:
# question    3266
# answer      2802
# other        902
# header       441
# Name: label, dtype: int64

# %%
data.isna().sum()
# Out:
# box        0
# text       0
# label      0
# words      0
# linking    0
# id         0
# dtype: int64

# %%
data
# Out:
#                        box                                            text  \
# 0     [394, 145, 433, 162]                                           ITEM:
# 1     [109, 112, 151, 129]                                           DATE:
# 2     [110, 140, 159, 155]                                          BRAND:
# 3     [109, 183, 168, 198]                                         SUMMARY
# 4     [175, 184, 193, 195]                                              OF
# ...                    ...                                             ...
# 7406  [397, 881, 528, 914]  Topline w/o 12 /18 /95 Final Report 12/ 31/ 95
# 7407  [577, 742, 635, 759]                                        $100 600
# 7408  [398, 761, 560, 779]                          Revised Costs (if any)
# 7409  [397, 788, 532, 806]                             Fieldwork Schedule:
# 7410  [204, 642, 295, 659]                                  A & G Research
#
#          label                                              words     linking  \
# 0     question   [{'box': [394, 145, 433, 162], 'text': 'ITEM:'}]   [[0, 15]]
# 1     question   [{'box': [109, 112, 151, 129], 'text': 'DATE:'}]   [[1, 13]]
# 2     question  [{'box': [110, 140, 159, 155], 'text': 'BRAND:'}]   [[2, 14]]
# 3     question  [{'box': [109, 183, 168, 198], 'text': 'SUMMAR...          []
# 4     question      [{'box': [175, 184, 193, 195], 'text': 'OF'}]          []
# ...        ...                                                ...         ...
# 7406    answer  [{'text': 'Topline', 'box': [398, 883, 443, 89...  [[59, 60]]
# 7407     other  [{'text': '$100', 'box': [577, 742, 606, 757]}...          []
# 7408  question  [{'text': '', 'box': [398, 761, 409, 774]}, {'...          []
# 7409  question  [{'text': 'Fieldwork', 'box': [397, 788, 464, ...  [[63, 58]]
# 7410    answer  [{'text': 'A', 'box': [204, 642, 214, 657]}, {...  [[47, 64]]
#
#       id
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
# ...   ..
# 7406  60
# 7407  61
# 7408  62
# 7409  63
# 7410  64
#
# [7411 rows x 6 columns]

# %% [markdown]
# Are there natural language texts, which requires bigger model to understand the whold sentence, or more like a short text string?

# %%
data.to_csv('train_data.csv', index=False)

# %%
data.loc[247]
# Out:
# box                               [496, 204, 502, 210]
# text
# label                                         question
# words      [{'box': [496, 204, 502, 210], 'text': ''}]
# linking                                             []
# id                                                   5
# Name: 247, dtype: object

# %%
data['text'].str.len().describe()
# Out:
# count    7411.000000
# mean       16.993118
# std        29.437967
# min         0.000000
# 25%         5.000000
# 50%        10.000000
# 75%        18.000000
# max       706.000000
# Name: text, dtype: float64

# %%
data['text_len'] = data['text'].str.len()

# %%
index = data['text_len'].sort_values().index

# %%
data.loc[index].tail(1000)['text'].values
# Out:
# array(['GENERAL PROJECT DESCRIPTION', 'Cigarette Design, Permanent',
#        'NEWPORT RACING EVENT SURVEY', 'Quantities and Description:',
#        'Smoke Analysis PMO Analysis', 'IF SO, GIVE DATE AND TITLE:',
#        'H. J. Minnemeyer L. B. Gray', 'BMC/RMI/EPB JEM/DEC PRC/DRB',
#        '1. Productivity Improvement', 'AMES ASSAY FOR MUTAGENICITY',
#        '300 mm. tar, 100 mm acetone', 'Check Required ASAP/ PROMPT',
#        'Description of change order:', 'Own Brand - Dunhill Smokers:',
#        'O ORGANIZER (if applicable):', 'LD50 (95% CONFIDENCE LIMITS)',
#        'The report of the results of', '☐ Decrease Existing Revenues',
#        'Mr. Johnny Pedersen - Gallup', 'Consideration deferred until',
#        'SCIENTIFIC METING OF CHOICE:', 'TH 46 TCRC REGISTRATION FORM',
#        '1974- Jan. 1982 to Dec. 1981', '* Director - (G. L. Littell)',
#        'THE AMERICAN TOBACCO COMPANY', 'DOES WORK MERIT PUBLICATION?',
#        '* Advertising Creative Title', 'FAX TO THE FOLLOWING PERSON:',
#        '20. 285 1 (a), 1 (b), 1 (im)', '25% PG w/ SORBITOL #647/ 627',
#        'Borriston Laboratories, Inc.', '* Sr. Manager (B. J. Powell)',
#        '1973 91, 630. 53 A. B., Inc.', 'COMPOUND PHYSICAL PARAMETERS',
#        '1974 92, 131. 29 A. B., Inc.', 'System is not functioning as',
#        'Paul Schickedantz, Jack Reid', 'Sister- -Chromatid Exchanges',
#        '1975 84, 309. 94 A. B., Inc.', '☐ Increase Existing Revenues',
#        'Total Pressure Drop (encap.)', 'Quality of Hospitality Tent:',
#        '(Including this cover sheet)', 'AB Research Associates, Inc.',
#        'SPECIAL PROMOTION EVALUATION', 'THE AMERICAN TOBACCO COMPANY',
#        'SPECIAL PROMOTION EVALUATION', 'WERE QUANTITIES APPROPRIATE?',
#        'SHOULD PROMOTION BE REPEATED', 'STYLE LIGHTS PROGRESS REPORT',
#        'WERE QUANTITIES APPROPRIATE?', 'CLUB, CASH & CARRY, ETC...):',
#        "3. Date of claimant's birth:", 'THE AMERICAN TOBACCO COMPANY',
#        "Section Sales Manager's Name", 'Division (s) to be contacted',
#        'THE AMERICAN TOBACCO COMPANY', 'January 27, 1969 9: 00 a. m.',
#        'COMPOUND PHYSICAL PARAMETERS', 'Total Pressure Drop (encap.)',
#        'Preparation and Composition:', 'COMPOUND PHYSICAL PARAMETERS',
#        'LORILLARD TOE CO NYO - SALES', '- ADVERTISING CREATIVE TITLE',
#        'NUMBER OF CIGARETTES SMOKED:', 'OLD GOLD Straights + 3% KNO3',
#        'Mrs. Illinois Beauty Pageant', 'Camilo Concha/ Andrea Suarez',
#        'ORDER THROUGH YOUR SUPPLIER.', 'Organization/ Employer Name:',
#        'Reason(s) for Recommendation', 'The American Tobacco Company',
#        'K. A. Hutchison S. A. Howard', '(indicate if attached pages)',
#        'THE AMERICAN TOBACCO COMPANY', 'Quality of Hospitality Tent:',
#        '1990 Customized Merchandising', 'Upper Madisor Avenue Festival',
#        'K:\\CLIENTS\\5002\\FACTSHIT.COM ',
#        'Prev. or Recommended Supplier', 'Suggestions/ Recommendations:',
#        'Director, Product Development', 'Signature of Hetail Purchaser',
#        'Description: CAPRI Expansion:', 'Current VICEROY 84 (#647/ 647',
#        'The Corporation Trust Company', 'Quantity, Cartons of 200 each',
#        '1825 Eye Street, NW Suite 800', 'COUPON CODE REGISTRATION FORM',
#        'Lorillard - Organic Chemistry', 'STUDY TITLE & PROPOSAL NUMBER',
#        'Prev. or Recommended SupplIer', 'SHOULD PROMOTION BE REPEATED?',
#        'Reason (s) for Recommendation', 'MARKET RESEARCH AUTHORIZATION',
#        'Reason(s) for Recommendation:', 'Lorillard - Organic Chemistry',
#        'COUPON CODE REGISTRATION FORM', 'EFFECTIVENESS OF ADVERTISING:',
#        'productivity improvement, new', 'STUDY TITLE & PROPOSAL NUMBER',
#        'Suggestions/ Recommendations:', 'Moisture content (ex-catcher)',
#        'THE CORPORATION TRUST COMPANY', 'PERCENT ACTIVES (Non -water):',
#        'SPECIFICATION CHANGE PROPOSAL', 'COUPON CODE REGISTRATION FORM',
#        'COUPON CODE REGISTRATION FORM', 'COUPON CODE REGISTRATION FORM',
#        'COMPLETE EITHER A OR B BELOW:', 'REQUESTED IMPLEMENTATION DATE',
#        'Equivalent Packaging Material', 'NOT TO BE CHARGED BY SUPPLIER',
#        'SCIENTIFIC JOURNAL OF CHOICE:', 'MA ETING RESEARCH AUTHORIZ ON',
#        'Lorillard - Organic Chemistry', 'COUPON CODE REGISTRATION FORM',
#        'the quality of the sunglasses', 'NUMBER OF SAMPLING PERSONNEL:',
#        'Signature Employer or Designee', 'Best Cigarette Co., Mentor, OH',
#        '2. Use moregeneral categories.', 'several weeks after completion',
#        'Background Problem Definition:', 'Affected Ch. 20 Appropriations',
#        'Total Pressure Drop (unencap.)', 'LORILLARD COMPOUND CODE NUMBER',
#        'Long Range Fiscal Implications', 'Jimmy H. Bell B. Sc. Scientist',
#        '42nd- 57th Street, New York NY', 'Reason (s) for Recommendation:',
#        '1993 AVG. MONTHLY USAGE (LBS.)', 'Dayton DAYTON NEWS (4 /23 /72)',
#        'If not approved state reasons.', 'Total Pressure Drop (unencap.)',
#        'VS. CURRENT YEAR (INCR.) DECR.', 'ON - Carton Instant Redeemable',
#        '25% PG w/ SORBITOL (#647/ 627)', 'Expansion of Existing Business',
#        'Received by REGULATORY AFFATRS', 'University of Wisconsin System',
#        'Philip Morris Management Corp.', 'Initial Production Requirement',
#        '68th -86th Street New York, NY', 'Current VICEROY 84 (#627/ 647)',
#        '(919) 378- 001 Ron Goldbrenner', 'LORILLARD HOUS. NEW YORK SALES',
#        'CHAMP S/ L TRIAL SPECIFICATION',
#        'Competitive Proposals Obtained:',
#        'Special Instructions & Comments',
#        'Mademoiselle, New York Magazine',
#        'Adjusted Total Cost of Project:',
#        'Preliminary Program Information',
#        '(Recommended Proposal Attached)',
#        'Adjusted Total Cost of Protect:',
#        'BETWEEN THE ACTS 25 %% mm. Butt',
#        'Competitive Proposals Obtained:',
#        'MALE AND FEMALE MENTHOL SMOKERS',
#        'high volume file maintenance or',
#        '(Recommended Proposal Attached)',
#        'John J. Mulderig C/O Mike Baker',
#        'Background / Problem Definition',
#        'CICARETTE TEST STATION (CT5400)',
#        '(submit by 30 days after event)',
#        'ATTACHMENTS (Check if Included)',
#        'Est. Annual Product Cost Change',
#        'Sales Personnel to be contacted',
#        'To Be Deducted from 1998 Budget',
#        'Adjusted Total Cost of Project:',
#        '1997 SPECIAL EVENT REQUEST FORM',
#        'COMMENTS BY MANAGER OR DIRECTOR',
#        'Andrew H. Tisch (Print or type)',
#        'Amount earned but not received:',
#        'Compensation received lobbying:',
#        'LUCKY STRIKE Filter and VICEROY',
#        'Competitive Proposals Obtained:',
#        'REGISTRY NUMBER (IF applicable)',
#        'Direct Mail Conversion Research',
#        'PLEASE DELIVER TRANSMISSION TO:',
#        'Excellent but quickly depleted.',
#        'Total Authorized Project Amount',
#        'ADJUSTED TOTAL COST OF PROJECT:',
#        'Competitive Proposals Obtained:',
#        'SPECIAL EVENT INFORMATION SHEET',
#        '(submit by 30 days after event)',
#        'CMS Amerada Hess Dispenser Sign',
#        'Extra banquet tickets @ $ 40.00',
#        'RJR Mailfile Table Update Sheet',
#        'Tipping and Tipping Application',
#        'MARKETING RESEARCH AUTHORI TION',
#        'BRC Codes w81 carton order form',
#        'To Be Deducted from 1999 Budget',
#        'Section 18 Narl Chain Walgreens',
#        'TOP- LINES MENTHOL PRODUCT TEST',
#        'Tipping and Tipping Application',
#        '(Tier system) at the same time.',
#        'SPECIAL EVENT INFORMATION SHEET',
#        'PROTECTIVE PRECAUTIONS REQUIRED',
#        'Perforation Type & No. of lines',
#        'COMPETITIVE PROMOTIONAL ACTIVITY',
#        'MAGAZINE SCORES AUDIENCE STUDIES',
#        'Passport Winter Program Ad- EMRO',
#        'MARKETING RESEARCH AUTHORIZATION',
#        'Sample Specifications Written By',
#        'Commited to Date: (Current Year)',
#        'Maintenance of Existing Business',
#        'Hotel /Motel reservations needed',
#        'Submit not later than 1 November',
#        '☑ ) POOR QUALITY ORIGINAL. faded',
#        'Final Report Due (Supplier Rpt.)',
#        'COMPETITIVE PROMOTIONAL ACTIVITY',
#        'PROTECTIVE PRECAUTIONS REQUIRED:',
#        'Kent, Newport, True and Old Gold',
#        'Excellent appearance (18 holes).',
#        'Excellent appearance (18 holes).',
#        'Filter Plug Pressure Drop encap.',
#        'Print Position (from filter end)',
#        'Line Drawings of Football Scenes',
#        '(Indicate N/A If Not Applicable)',
#        'DATE SUBMITTED AND DEPT. MANAGER',
#        'Print Position (from filter end)',
#        'Lorillard Metro Golf Outing 1997',
#        'ROUTE OF COMPOUND ADMINISTRATION',
#        '999 Grant Avenue, P. O. Box 2109',
#        'M. Hamann P. Harper, P. Martinez',
#        '(502) 568-7313 or (502) 568-8319',
#        'Special Equipment/ Material Cost',
#        '(502) 568-7313 or (502) 568-8319',
#        'Office of the Secretary of State',
#        'Sample specifications written by',
#        'ROUTE OF COMPOUND ADMINISTRATION',
#        'R. J. REYNOLDS AND PHILIP MORRIS',
#        "SAMPLE 10'S (400 PACKS PER CASE)",
#        "SAMPLE 10'S (400 PACKS PER CASE)",
#        'Final Report Due (Supplier Rpt.)',
#        'Solvent Composit to % V. O. C. s',
#        'Sample Specifications Written By',
#        'comments to the Quality Council.',
#        'Major Airport Nearest your home:',
#        'Mr. M. A. Peterson Mr. T. H. Mau',
#        'K001 vs. Marlboro Menthol Lights',
#        '20 CENTS OFF PACK COUPON/STICKER:',
#        'PLEASE TRANSMIT THIS DOCUMENT TO:',
#        'DEPARTMENT EXPENSE BUDGET SUMMARY',
#        'Bogotá, Medellin and Barranquilla',
#        '383 Madison Avenue New York 10017',
#        'SHIPMENT TO ARRIVE NOT LATER THAN',
#        'Perforation Type and No. of lines',
#        'HAZLETON LABORATORIES AMERICA INC',
#        "CARLTON Filter 100's - 4 Mg Laser",
#        'and Exper. Ther. , 90: 99 , 1948.',
#        'ADMIN CTR/MGMT CTR. (AS REQUIRED)',
#        'Committed to Date: (Current Year)',
#        'Previous Commitments This Project',
#        'No Side Stream Smoke Focus Groups',
#        'This Change (From Current Budget)',
#        'Committed to Date: (Current Year)',
#        '(Condition And Rendition of Copy)',
#        'NEWSPAPER SCORES AUDIENCE STUDIES',
#        'Committed to Date: (Current Year)',
#        'PLEASE TRANSMIT THIS DOCUMENT TO:',
#        'CARDINAL CIGARETTES (11 PACKINGS)',
#        'Manager, H.J. Minnemeyer Research',
#        'application or technology failure',
#        'SPECIAL INSTRUCTIONS WHILE DOSING',
#        'MRD00005 (revised 3/ 20) PPs 0425',
#        'SPECIAL INSTRUCTIONS WHILE DOSING',
#        'Final Film Supplied Combined Blue',
#        'This Change: (From Current Budget',
#        '1976 $ 40, 921. 30 by A. B., Inc.',
#        'Use Separate Form For Each Change',
#        '☐ Increase Existing Appropriation',
#        'HAZLETON LABORATORIES AMERICA INC',
#        'LORILLARD 25 JAX SALES GENERAL NY',
#        'General Merchandising Nonspecific',
#        '☐ Decrease Existing Appropriation',
#        'MEMPHIS, PHILADELPHIA, PITTSBURGH',
#        'Estimated Man Hours for Completion',
#        'TRUE $3.00 CARTON COUPON PROMOTION',
#        'Sales Personnel to be worked with:',
#        'MAVERICK SPECIALS- PROGRESS REPORT',
#        'This Change: (From Current Budget)',
#        'Tuesday 3 /13 and Wednesday, 3 /14',
#        'PROJECTED CURRENT YEAR EXPENSES 19',
#        "LORILLARD DIVISION DE LOEW'S CORP.",
#        'COLLATERAL MERCHANDISING MATERIALS',
#        'lobbyist for lobbying? (yes or no)',
#        'MAJOR MKT. AND MKT. RESEARCH STEPS',
#        '1000 lines B&W 1750 lines 2- color',
#        'Filter Plug Pressure Drop (encap.)',
#        'This Change: (From Current Budget)',
#        'ALL MATERIALS HAVE BEEN CANCELLED.',
#        '12/08/97 09: 01 FAX 1 732 583 8977',
#        'Interviews divided among 3 gorups:',
#        '(See SOP FOX Biological Solutions)',
#        'THIS CHANGE: (From Current Budget)',
#        'CAN TIME BE SPARED FOR COMPLETION?',
#        'FOR PURCHASING DEPARTMENT USE ONLY',
#        '(202) 662 -6280 Telecommunications',
#        'M. BOGGIANO Director) FRANK TOWERS',
#        'RESPONSE CODE REQUEST CONFIRMATION',
#        'PROJECT STATUS REPORT CONFIDENTIAL',
#        'ACCEPT/ REJECT (as per 58.185 (c))',
#        'TELECOPIER TRANSMITTAL COVER SHEET',
#        'SPECIFICATION CHANGE NUMBER 84- 79',
#        'Equivalent Filter/ Paper/ /Tipping',
#        'This Change: (From Current Budget)',
#        '(See SOE for Biological Solutions)',
#        'DATE FORWARDED PROMOTION SERVICES:',
#        'MARKETING RESEARCH PROJECT APPROVAL',
#        'Cellulose Nitrate Wet w /2 Propanol',
#        'Authorized Signature Telephone No. ',
#        'RALEIGH (BELAIR portion not tested)',
#        'Regulation of Smoking Public Places',
#        'Hong Kong: Cigarette Market Monitor',
#        'AVERAGE DAILY EFFECTIVE CIRCULATION',
#        '30 sheet Posters (White Background)',
#        'Distance from your home to airport:',
#        '680534113 RODUCED FROM B&W WEB SITE',
#        "True 100's, Regular and Menthol tar",
#        'fix program error new business need',
#        '681925993 RODUCED FROM B&W WEB SITE',
#        'Dr. H. J. Minnemeyer Ms. L. B. Gray',
#        'functionality, nice to have feature',
#        '12009596 PRODUCED FROM B&W WEB SITE',
#        'Chairman - Professor of Cytogenetic',
#        'Please Deliver as soon Possible To:',
#        'BROWN & WILLIAMSON BID REQUEST FORM',
#        'Alberto Marcheggiano Kyu Yeon Hwang',
#        'Previous $ Commitments This Project',
#        'DR. HUGHES, MESSRS. ALAR, SANDEFUR,',
#        'TEXT: Over 500 Prizes To Be Awarded',
#        'Order Taken By Sales Representative',
#        'Previous $ Commitments This Project',
#        'Dr. H. J. Minnemeyer Ms. L. B. Gray',
#        'This commercial was tested in color.',
#        'Filter Plug Pressure Drop (unencap.)',
#        'San Diego SAN DIEGO UNION (4 /23 /72',
#        'A. T. Co. Tar & Nicotine Change Form',
#        'FISCAL ESTIMATE AD MBA 23 (Rev 11/80',
#        '970518461 PRODUCED FROM B&W WEB SITE',
#        'Maria Helena Argüelles/ Edwin Garcia',
#        '220076948 PRODUCED FROM B&W WEB SITE',
#        'Estimated cost of the study will be:',
#        '597133637 PRODUCED FROM B&W WEB SITE',
#        'This form was placed before Bates ID',
#        'Senior VP Marketing (to $ 1,000,000)',
#        '680115980 PRODUCED FROM B&W WEB SITE',
#        'Filter Plug Pressure Drop (unencap.)',
#        'Compliance with Outside Requirements',
#        'C. M. WIECHMANN, D. M. , LUBBOCK, TX',
#        'TOP- LINES NON- MENTHOL PRODUCT TEST',
#        'James R. Langevin Secretary of State',
#        'Marketing and or Research Objectives',
#        '176103236 PRODUCED FROM B&W WEB SITE',
#        '462231045 PRODUCED FROM B&W WEB SITE',
#        'Senior VP Marketing (to $ 1,000,000)',
#        'Pick The Winners And Win Up $ 5 ,000',
#        'Topline Oral presentation w/ o 5/ 18',
#        'PRODUCT CLASSIFICATION (Circle Dne):',
#        'People, Rolling Stone, Cosmopolitan,',
#        'Late Registration Fee: (after August',
#        'Sample Requisition [Form 02: 02: 06]',
#        'Sample number on each pack and carton',
#        'Univ. of Minnesota School of Medicine',
#        '670121460 PRODUCED FROM B& W WEB SITE',
#        'Proiected External Authorization Date',
#        'ADMIN CTR/MGMT CTR PURCHASE ORDER NO.',
#        'Legal Approval Recommended/ Required:',
#        'R. Schoenfein S. Dammers P. Hendricks',
#        'To be placed on tables by B & W Reps.',
#        'WILL BE ARBITRARILY SHIPPED TO STORE.',
#        'ORIGINAL SIGNED PROJECT SHEETS TO PSO',
#        "This Amount (From Next Year's Budget)",
#        'ORIGINAL SIGNED PROJECT SHEETS TO PSO',
#        'we wted with line Whortly how Motion ',
#        'Final Written presentation w/ o 5/ 25',
#        'Part of salary received for lobbying:',
#        'HAS WORK BEEN REPORTED IN MANUSCRIPT ',
#        '+ - 10% Contingency Final Report Inc.',
#        'JAN 19 96 05:27 PM AB RESEARCH ASSOC.',
#        'DATE FORWARDED TO PROMOTION SERVICES:',
#        'Dr. F. J. Schulz Dr. H. J. Minnemeyer',
#        'SCHEDULE: DATE OR INVENTORY DEPLETION',
#        'COMPETITIVE ACTIVITIES AND PROMOTIONS',
#        'Abnormal Human Chromosome Complements',
#        'Monthly Organization/ Employer Report',
#        '$3 Off Store Redeemable Carton Coupon',
#        'COMPETITIVE ACTIVITIES AND PROMOTIONS',
#        'COMPETITIVE ACTIVITIES AND PROMOTIONS',
#        'ADVERTISING AND SELLING AUTHORIZATION',
#        'SHORT STOP FOOD MARTS. LOUISVILLE, KY',
#        'Low tar, king size, filter, hard pack',
#        '440026083 PRODUCED FROM B &W WEB SITE',
#        'ADVERTISING AND SELLING AUTHORIZATION',
#        "This Amount (From Next Year's Budget)",
#        'LAURENCE, CHARLES, FREE & LAWSON, INC.',
#        'University of Hawai - Dept. of Anatomy',
#        'Human Linkage Map based on DNA Markers',
#        'AARBERG -STRAHAN INKS & COATINGS CORP.',
#        'Type of product, size(s) & list price:',
#        'Brown & Williamson Tobacco Corporation',
#        'LUCKY STRIKE LOW Tar Filters Box- 100%',
#        'P. O. Box 21688 Greensboro N. C. 27420',
#        'several weeks after completion of work',
#        'SAFETY COMMENTS SUGGESTED- PROCEDURES)',
#        "VICEROY Rich Lights 100' s 20' s Label",
#        "Harley Davidson 100's Progress Report.",
#        'Compensation/ Expenditure Information:',
#        '250 VICEROY/ 125 Marlboro/ 125 Winston',
#        'KOOL Lights KS- white tip- ping masked',
#        'QUALITY ASSURANCE REPORT CERTIFICATION',
#        "This amount: (From Next Year's Budget)",
#        'REPORTABLE EXPENDITURES (In Thousands)',
#        'NEW EXPORT PRODUCT DEVELOPMENT CHARTER',
#        'If yes, please complete the following.',
#        'Kwb Kenneth W. Smits Technologist - QA',
#        '466840246 PRODUCED FROM B & W WEB SITE',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION',
#        'Sworn to and subscribed before me this',
#        '2-9-90 Betty J. murphy (Notary Public)',
#        'One Park Avenue, New York, N. Y. 10016',
#        'SEE ATTACHED COPY OF CIRCULAR NO. 4848',
#        '210180429 PRODUCED FROM B & W WEB SITE',
#        'GREY ADVERTISING INC. - MEETING REPORT',
#        'DECISION TREE ESTIMATION OF TOXIC RISK',
#        "VICEROY Rich Lights 100' s 20' s Label",
#        '210350475 PRODUCED FROM B & W WEB SITE',
#        'SEE ATTACHED CORRESPONDENCE REGARDING:',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION',
#        'WAVE 3 (87 –114) AND WAVE 4 (87 -115) .',
#        'Product Development, John H. M. Bohlker',
#        '9 0 % CLASSIFIED CALLS 2 % ANNUAL CALLS',
#        'Birmingham BIRMINGHAM NEWS (4 /23 /72)\uf702',
#        'Velcro on strap did not hold. Two right',
#        'Current VICEROY 84 25% PG with SORBITOL',
#        'Director Forecasting Mkt (to $ 250,000)',
#        'V. Colvellm Asst. Secy. 277 Park Avenue',
#        'In the future, please specify where the',
#        'KOOL Natural Lights Packaging - Round I',
#        'Director Market Research (to $ 250,000)',
#        'to be assigned by Brown & Williamson USA',
#        '*This was a combination ad with RALEIGH.',
#        '30- SHEET POSTING COMPLETION REPORT FORM',
#        'CARLTON "Free" Carton" Direct Mail Piece',
#        'DATE POSTERS RECEIVED FROM LITHOGRAPHER:',
#        'Project Type (Product Test, A & U, etc.)',
#        'The protocol for this study is attached.',
#        'Fax to Field Payments at (502) 588- 7826',
#        'Final Report Due (Supplier Rpt.) Wave(s)',
#        'Dr. Don Leyden, Dept. Scientific Affairs',
#        'ESTIMATED TARGET DATE- ORIGINAL COMMENTS',
#        'Ms. Joy Weathers (Sales) 312/ 426 - 8000',
#        'Describe Possible Solutions And Benefits',
#        '3-Hydroxy-3-methylbutanoic acid (Tur 13)',
#        'NUMBER OF PAGES (INCLUDING COVER SHEET):',
#        'DOMESTIC (Recommended Proposal Attached)',
#        'EXPERIMENTAL PATHOLOGY LABORATORIES, INC.',
#        'I will participate in the Golf Tournament',
#        'Marketing Research - CPT Initiating Brief',
#        'AMOUNT OF CHANGE INCREASE ): (CIRCLE ONE)',
#        'Competitors Brands - Mild7 Lights Smokers',
#        '- 420 English Street Greensboro, NC 27405',
#        'Recent actions regarding above solicitor ',
#        'Please print name of Employer or Designee',
#        'ESTIMATE OF TIME NEEDED TO COMPLETE WORK:',
#        'process, or implement strategic direction',
#        'S. WILLINGER (3) ☑ RESEARCH GROUP MANAGER',
#        'Final Report Due (Supplier Rpt.) Wave (s)',
#        '" KALEIDOSCOPE - - GONE WITH THE WIND " *',
#        '22, 320 (Indy East & West) NO SHOW SAMPLES',
#        'The Promotion can be improved by upgrading',
#        '*Subject to change due to local conditions',
#        "46th Tobacco Chemists' Research Conference",
#        'MAVERICK SPECIALS MENTHOL- PROGRESS REPORT',
#        '14 Day Single Dose Subacute Toxicity Study',
#        'CAPRI EXPANSION A&U - CALIFORNIA - WAVE 4.',
#        'Registry of the Toxic Effects of Chemicals',
#        'URBAN CENTER INITIATIVE ASSIGNMENT PROFILE',
#        'reporting requirement which is not part of',
#        'Decision of Committee on Present Request -',
#        '(DOMESTIC) (Recommended Proposal Attached)',
#        'Package Fixture Circle-K Convenient Stores',
#        'Total number of pages including this page:',
#        'Return this form in the envelope provided.',
#        "Y- 1 Ultra 100' s vs. Winston Ultra 100' s",
#        'Market Research - Initiating Project Brief',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION B&W',
#        'Increase Costs - May Be Possible to Absorb',
#        'Lorillard Tobacco Company Houston N., Texas',
#        'Script(s) (and/ or story board(s)) cleared:',
#        '4. Case involves (check appropriate boxes):',
#        '150 Males, 25 ~ 39 years old, ABC+ who live',
#        'TOTAL REPORTABLE EXPENDITURES FOR VARIETYI:',
#        'THE AMERICAN TOBACCO COMPANY (LUCKY STRIKE)',
#        'MIS PROJECT REQUEST PART I - CLIENT REQUEST',
#        'BULL DURHAM Full Flavor King Size Cigarettes',
#        'FOLLOW DEPARTMENT AND COMPANY SAFETY MANUALS',
#        'Acute Intraperitoneal Toxicity Study in Rats',
#        'Ann C. Stringfield Literature M.L.S. Chemist',
#        'Dunhill Lights Kent Super Lights Mild 7 This',
#        'THE FOLLOWING INFORMATION MUST BE FURNISHED:',
#        'The attached was obtained from Mackoul Dist.',
#        'FOLLOW DEPARTMENT AND COMPANY SAFETY MANUALS',
#        'Enter Federal Employer Identification Number',
#        'A. REID, DIVISION MANAGER, SAN FRANCISCO, CA',
#        'OUTDOOR AND PRINT ADS HAVE BEEN EFFECTIVE IN',
#        'Director Research Development (to $ 250,000)',
#        'KOOL Lights KS vs. Bright KS Product Monitor',
#        'Have you contacted your Manager/ Supervisor?',
#        'NG DOCUMENTS WERE FOUND WITHIN THE ORIGINAL:',
#        'PAGE NUMBER(S) WERE MISSING IN THE ORIGINAL.',
#        'Date of Final Report (Review Completed Date)',
#        'Solubility (See SOP for Biological Solutions)',
#        '% OF DISTRIBUTION ACHIEVED IN RETAIL OUTLETS:',
#        '% OF DISTRIBUTION ACHIEVED IN RETAIL OUTLETS:',
#        'EFFECTIVENESS OF SELL (REPORT ON OCT 3 ONLY).',
#        '5. Types of Local Governmental Unit Aflected:',
#        'Reimbursements for expenses (please itemize):',
#        'who being duly sworn, says that (he) (she) is',
#        'KENT HEAVY UP TEST DIRECT MAIL CPNS New Names',
#        'sides of velcro on same glass did not adhere.',
#        'Source of Business - Local Premium KS Smokers',
#        '% OF DISTRIBUTION ACHIEVED IN RETAIL OUTLETS:',
#        'CONTROL REVERTANTS PER PLATE TOON MI SOLVENTI',
#        'Application: tipping, carton end flaps, etc.)',
#        'B164 is insoluble according to this procedure',
#        'Allowable Grade Substitutions for Export CPCL',
#        'Manager, please contact suggester and forward',
#        'VAL THURMAN, DIVISION MANAGER, LOUISVILLE, KY',
#        '(202) 662 -5942 Leslie L. Daniels - Secretary',
#        'NAMES OF OTHER PERSONS COLLABORATING IN WORK:',
#        'CONTROL AFVERTANTS PER PLATE (0.05 ml SOLVENT)',
#        '250 Males (100 smokers, 25 ~ 29 years old, 150',
#        'READ REVERSE SIDE BEFORE FILLING OUT THIS FORM',
#        'Advance Registration Fee: (prior to August 10)',
#        'APPLICATION (Circle One and Briefly Describe):',
#        'Sign & Print Names) (See Instructions On Back)',
#        'INBIFO Institut für biologische Forschung GmbH',
#        'Recommended Brand(s) and Promotional Activity:',
#        '575 Lexington Avenue, New York, New York 10022',
#        '35 WEST WACKER CHICAGO. IL 30601 312- 588 5800',
#        'CARTON PROMOTION SWEEPSTAKES (SEE ATTACHMENTS)',
#        'Information and hearsay from outside contacts:',
#        'Topline w/o 12 /18 /95 Final Report 12/ 31/ 95',
#        'Before me a Notary Public, personally appeared',
#        'Asumptions Used in Arriving at Fiscal Estimate',
#        'List any changes of address telephone numbers:',
#        'SAFETY COMMENTS (SUGGESTED HANDLING PROCEDURE)',
#        '* UP TO AND INCLUDING $ 25,000 ** OVER $ 25,000',
#        'TOTAL # OF INDEPENDENT NEWPORT #1 CLUB OUTLETS:',
#        'Los Angeles Football Fans Chicago Football Fans',
#        '(26) TOTAL REPORTABLE EXPENDITURES FOR VARIETY:',
#        '1,600 posters plus 5% overrun (80) $ 16.00 each',
#        '9200 EESAURG TURNPIKE VIENNA VIRGINIA 22180 USA',
#        "Amelia 100's Candidates: (NM-FT and NM- Lights)",
#        'Break - out separately byl packing as indicated',
#        'RICHLAND Kings (Soft Pack) -Duty Free (Phoenix)',
#        'APPROXIMATE % OF RETAIL CALLS SECURED BY GLASS:',
#        'Qualitative Research (Product Test, A & U etc.)',
#        '1. Drop the category specifications altogether.',
#        'The following document, including cover page is',
#        'STATE OF RHODE ISLAND AND PROVIDENCE PLANTATIONS',
#        'TOTAL # OF INDEPENDENT SPECIAL EMPHASIS OUTLETS:',
#        'MS. JACKIE KEY B&W LOUISVILLE, KENTUCKY U. S. A.',
#        'ics similar to True King Size, 5mg. tar product.',
#        'Sneak Preview Confirmation Call- Charlotte Tests',
#        "HARLEY DAVIDSON 100'S CIGARETTES PROGRESS REPORT",
#        '9200 LEESBURG TURNPIKE VIENNA VIRGINIA 22180 USA',
#        'LAKE- NEW PACK: 40 (with BELAIR Badmin- ton: 20)',
#        'If there is a transmission problem, please call:',
#        'Jul 22 93 02:42PM LORILLARD TOBACCO 919 373 6917',
#        'TOTAL # OF SP EMPHASIS OUTLEIS WITH DISTRIBUTION',
#        'AMERICAN BROADCASTING COMPANY TELEVISION NETWORK',
#        'Total aldehyde analysis in cigarette mainstream ',
#        'Pittsburgh Pittsburgh PUTSBURGH PRESS (4 /23 /72',
#        'AMERICAN BROADCASTING COMPANY TELEVISION NETWORK',
#        '395 DYSTER POINT BLVD SUITE 415 S. SAN FRANCISCO',
#        '2. ESTIMATED TEST PRODUCT QUANTITIES (PER MARKET)',
#        'Excellent. Continues to drive all carton business',
#        "HARLEY- DAVIDSON 100'S CIGARETTES PROGRESS REPORT",
#        'Circuit Court, Dade County, Florida. No. 69 -1351',
#        'R&D QUALITY IMPROVEMENT SUGGESTION/ SOLUTION FORM',
#        'Refrig erate in amber bottle at no more than 8 C.',
#        '6DR IV per II Revised MRA request one on LS to be',
#        '25% Replacement of Propylene Glycol With SORBITOL',
#        'APPROVED MARKETING PROJECT EXPENSE RECOMMENDATION',
#        'SUGGESTION: (Describe Current Situation and Idea)',
#        'Amendment (Attach additional sheets as necessary)',
#        'Kool KS. 9 mg tar, @ 0. 51% menthol white tipping',
#        'If a material or dimensional change also involved?',
#        '1. STATES AND CITIES* SELECTED TO RECEIVE PRODUCT:',
#        'R. E. Klein, Regional Sales Manager, Cleveland, OH',
#        'Pre- Sell Booklet /Coupon Maverick /Harley B1 G1 F',
#        'Company Improvements & Administrative Requirements',
#        '200 PARK AVENUE NEWYORK NY 10166 4193 212 294-6700',
#        'Name of spouse participating in the guest programs',
#        'Survival after repeated doses over a 14 day period',
#        'KMDP ANALYSIS UTILIZING BLACK SWITCHING STUDY DATA',
#        'IF YOU DO NOT RECEIVE ANY OF THE PAGES, PLEASE CALL',
#        'EFFECTIVENESS OF PRE- SELL (REPORT ON OCT. 3 ONLY).',
#        '(To be filled out by Marketing Research Department)',
#        'Autos Mgr. Trade & Consumer Research (to $ 100,000)',
#        '* PLEASE ALLOW 6 WEEKS FOR PROCESSING YOUR REQUEST.',
#        'Part of Final Report to be Amended (Exact location)',
#        'MAVERICK SPECIALS EXPANSION MARKETS PROGRESS REPORT',
#        'Litchfield, J. T. and Wilcoxin F. , J. of Pharmacol',
#        'Brookhaven National Laboratory - Medical Department',
#        'TYPE OF SPECIFICATION CHANGE (Check all that apply)',
#        'K. AUGUSTYN. L. GIORDANO, M. McGLYNN, S. RAPISARLDI',
#        'A. L. EVERETT, MANAGER, CHAIN ACCOUNTS - ATLANTA, GA',
#        '2a. ESTIMATED TOTALS BY PRODUCT ALL MARKETS COMBINED',
#        '.922 1 .059 .54 .20 20 .2 7 .6 62 .4 1 .07 .41 61 .7',
#        'Andrew G. Kallianos, Richard K. Means, James D. Mold',
#        'MUST BE AUTHORIZED BY THE DEPARTMENT DIRECTOR OR THE',
#        'TOTAL # OF NUMBER ONE CLUB OUTLETS WITH DISTRIBUTION',
#        'EFFECTIVENESS OF PRE- SELL (REPORT ON FEB. 17 ONLY).',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION FILTER SCORES',
#        'LECONFIELD HOUSE CURZON STREET LONDON WIYIAS ENGLAND',
#        'Max A. Goldfarb 414 Biscayne Building Miami, Florida',
#        'CAPRI A&U EXPANSION - CALIFORNIA: WAVE 2 (87 -113) ,',
#        'RINCIPAL ORGANIZER (who will receive correspondence):',
#        'Refrigerate in amber glass bottle at no more than 8°C',
#        'This model/ type of sunglass was not received well at',
#        'Philip Morris Europe Fabriques de Tabac Reunies S. A.',
#        'a) Nature of work should be specified in exact terms.',
#        'Please make the necessary Field Trip arrangements for',
#        'GEMINI AWARENESS ATTITUDE & USAGE MONITOR. - PORTLAND',
#        'Mesothelioma and other asbestos- related lung disease',
#        'Dr. Dietrich Hoffman The Kettering New York, New York',
#        '(ONLY PARTIAL REGION CONTINUE WITH DIVISION(S) SCOPE)',
#        'to performed in Acure/Dermal Toxicology, building 18.',
#        '*PLEASE ALLOW 6 WEEKS FOR PROCESSING OF YOUR REQUEST.',
#        'Invitees stated the Newport hospitality tent was very',
#        'SPORTS MARKETING ENTERPRISES DOCUMENT CLEARANCE SHEET',
#        'PDL and John Brooks preparing charocal impregnated RC.',
#        'data correction which is not part of normal processing',
#        'CHICAGO, DALLAS/ FORT WORTH, INDIANAPOLIS, LOS ANGELES',
#        '(See General Order No. 29) (In Re: Complex Litigation)',
#        '21 AVENUE VICTOR HUGO 75 PARIS, FRANCE 33- 53 64 62 82',
#        'KOOL Parent regular smokers 50% -alternate smokers 50%',
#        'Arrival date and time (include airline and flight no.)',
#        '400 L. STREET N WASHWINGTON DC 20005 3502 202 371 5700',
#        '260 MADISON AVENUE, NEW YORK, NY 10016 (212) 213- 4646',
#        '42,000 lbs. of 80 lb Sterling C/ 2/ S - 36- 1/ 2" roll',
#        'AT (919) AT THE GREENSBORO BRANCH AS SOON AS POSSIBLE.',
#        'KOOL Parent regular smokers 50% -alternate smokers 50%',
#        'KOOL Parent regular smokers 50% -alternate smokers 50%',
#        "To evaluate Satin's overall performance and results of",
#        '1. THE FOLLOWING DOCUMENT IS DIVIDED INTO TWO SECTIONS.',
#        'REVISIONS TO SHELL (Other than Term Compensation or Job',
#        'TOTAL HOUSTON, GALVESTON, MINNEAPOLIS, ST. PAUL, DULUTH',
#        'LAB ANIMAL MEDICINE QUALITY ASSURANCE CONTRACTS Sponsor',
#        '90 % White - 10 % Black Age category 21 yrs. to 45 yrs.',
#        'PRELIMINARY FACT SHEET NEW FILING - ASBESTOS LITIGATION',
#        '31,000 lbs. of 80 lb. Sterling C/ 2/ S - 26- 1/ 2" roll',
#        'Prep. (line negatives, paper prints, camera/ stripping)',
#        '1. THE FOLLOWING DOCUMENT IS DIVIDED INTO TWO SECTIONS.',
#        'Adjustment due to timing of projects falling into 1988.',
#        'Room 43 State House Providence, Rhode Island 02903- 1105',
#        'Chain stores will not accept multiple Newport Promotions',
#        'b) R & D should advise if completion date cannot be met.',
#        'Reconstituted Tobacco Leaf Substitutions Export Formulas',
#        '150 Males, 25 ~ 39 years old, ABC+ who live Seoul/ Pusan',
#        '- R. J. REYNOLDS SPRING DIRECT ACCOUNT INCENTIVE PROGRAM',
#        'Ester of Modified Tricyclic Carboxylic Acid Jonrez IM824',
#        'Factory Cost Dept. Writer Development Center Sue Livesay',
#        'Weil, Carrol S., Biometrics, Vol. 8, No. 3., Sept. 1952,',
#        'Dr. William O. Iverson Pathologist Dr. Charley E. Gilmore',
#        'to be performed in Acute /Dermal Toxicology, building 18.',
#        'CONTAINS THE PROJECT DESCRIPTIONS AND SPECIFICATIONS FROM',
#        'Route 4 and Adams Station North Brunswick, NJ 08901- 0623',
#        'Harden- Kane, Inc. 666 Fifth Avenue New York, N. Y. 10103',
#        'MAVERICK SPECIALS NON- MENTHOL- EXPANSION PROGRESS REPORT',
#        'The Oncogene, the Fragile Site, and Nonrandom Aberrations',
#        'Material Safety Data Sheet is attached to Project Sheet 1.',
#        'INTERNATIONAL MARKETING RESEARCH CHANGE OF AUTHORIZED COST',
#        'DIRECT ACCOUNT AND CHAIN VOIDS (USE X TO INDICATE A VOID).',
#        'DIRECT ACCOUNT AND CHAIN VOIDS (USE X TO INDICATE A VOID).',
#        'Moisture analysis Menthol analysis Tar & nicotine analysis',
#        'Kool Milds KS Japan 9mg tar @ 0. 56% menthol white tipping',
#        '(ONLY IF PARTIAL REGION, CONTINUE WITH DIVISION (S) SCOPE)',
#        'Diethyl 3, 3-Dimethyl-2-oxo-1, 4-cyclopentanedicarboxylate',
#        '70,825 + +10 % (TOTAL 1987) +7.075 (2 -23 -88 77,900 TOTAL',
#        'SHOULD BE COMPLETED BY THE RESEARCH AGENCY AND RETURNED BY',
#        'This compound is judged non mutagenic in this test system.',
#        'PUBLIC COMMUNICATIONS APPROVAL SHEET The Tobacco Institute',
#        'Within 20 days after service, exclusive of day of service.',
#        'The attached is an addition to the I- 1725.001 Final Report',
#        'Record of confirmation calls for sneak preview appointments',
#        'NYSAWMD, INC. 211 EAST 43RD STREET, NEW YORK, NY 10017-4707',
#        'FEDERAL DISTRIBUTING CORPORATION CIGARETTE SAMPLING PROGRAM',
#        'OLD GOLD STRAIGHT Tobacco Blend Control for Sample No. 5030',
#        'This item was perceived by retailers and consumers as a low',
#        'Premiums packaged to large to store on a van. Could not get',
#        'This compound is judged non - mutagenic in this test system.',
#        'Any special dietary meal and/ you or your guest would prefer',
#        'BROWN & WILLAMSON 1994 COLLECTION PROTOCOPYING VARIANCE FORM',
#        'H/D 8 Pk. Wide Header 4 C/P + 2 Hits Day- Glo + Spot Varnish',
#        'Following physical/ visual properties out of specifications:',
#        'REVERSION RATE (TEST REVERSANTS/CONTROL REVERTANTS PER PLATE',
#        'Higher doses were impractical. The recommended safe dose for',
#        'Analytical Section is doing most of the work on vapor phase.',
#        'Event Attendance 100, 000 Hospitality Tent Attendance 35- 40',
#        'The protocol was approved in sponsor letter of June 6, 1983.',
#        'REVERSION RATE TEST REVERTANTS-CONTROL REVERTANTS PER PLATE)',
#        'MBTH- reagent for analysis of aliphatic aldehydes 7 / 5 / 67',
#        'Microbiological Associates 5221 River Rd., Bethesda MD 20816',
#        'PLEASE INCLUDE ONLY ONE TYPE OF MATERIAL ON THIS REQUISITION',
#        'The total sample size is 2,250. All smokers 21+ years of age.',
#        'PLEASE INCLUDE ONLY ONE TYPE OF MATERIAL ON THIS REQUISITION ',
#        'The following document, including cover page is 3 pages long.',
#        'SUBJECT TO THE FOLLOWING SUGGESTED REVISIONS: (itemize below):',
#        'This compound appears to act as a CNS depressant with symptons',
#        'Lorillard One Park Avenue New York, NY 10016 Attn: Neil Toumey',
#        'LUCKY STRIKE QUALITATIVE ADVERTISING RESEARCH - GATEWAY CITIES',
#        'Change in the time of the Pre- dose Biomicroscopic Examination',
#        'ESTIMATE OF TIME NEEDED TO PREPARE MANUSCRIPT FOR PUBLICATION:',
#        'For posting in Cincinnati, Covington and Tampa/St. Petersburg.',
#        'BLOTT, BUTLER, MIDDLETON, CHRISTENSEN, PEPPLES, SACHS FREEDMAN',
#        'The anticipated initiation date of this study is October 1983.',
#        'T. BAYLIES, L GIORDANO, V. LINDSLEY, M. MCGLYNN, S RAPISARLDI,',
#        '1330 Avenue of the Americas, New York, New York 10019 LT - 7777',
#        'IF YOU HAVE ANY QUESTIONS, PLEASE CONTACT THE FOLLOWING PERSON:',
#        'TAPE WILL FOLLOW AS SOON AS I RECEIVE IT FROM THE TAPE LIBRARY.',
#        'The anticipated completion date of this study is November 1983.',
#        'IF YOU HAVE ANY QUESTIONS, PLEASE CONTACT THE FOLLOWING PERSON:',
#        'Univ. of Texas Graduate School of Biomedical Sciences (Houston)',
#        'SERVICE REQUEST FROM R & D BY INTERNATIONAL LICENSEE OPERATIONS',
#        'Highest Quality. Teamwork, Do Right Things Right The First Time',
#        'ESTIMATE OF TIME NEEDED TO PREPARE MANUSCRIPT FOR PRESENTATION:',
#        'Harvard Medical School and Dr. Gary Huber Boston, Massachusetts',
#        'Applied Graphics Technologies 50 West 23rd Street, N.Y.C. 10010',
#        'Do you prefer airline seats in smoking or non- smoking section:',
#        'INBIFO bioloische Forschnung GmbH Fuggesstr 3- D- 51149 Cologne',
#        'Information from this exploratory research is directional only.',
#        'AT THE TIME OF REPRODUCTION, THE FOLLOWING NOTATTONS WERE MADE:',
#        'Only two bidders because third supplier has not yet signed B & W',
#        '1333 Avenue of the Americas, New York, New York 10019 LT 1- 7777',
#        'Dr. C. O. Jensen Mr. R. A. Wagner Mr. J. Berner Dr. A. W. Spears',
#        'PLEASE NOTIFY THIS DEPARTMENT OF ANY CHANGES THE CODE NUMBER(S).',
#        'PRESENT STATUS OF WORK (Cite progress reports where appropriate)',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION CAPITAL BUDGET PROJECT R&D',
#        'Tars and Nicotine, Taste Panel, Burning Time, Gas Phase Analysis,',
#        'Chairman/ CEO - Lorillard Tobacco Company (Job title or position)',
#        'X SPECIAL STORAGE Refrigerate in amber bottle at no more than * C',
#        'Date: PROJECT APPROVAL MARKET PLANNING AND INFORMATION DEPARTMENT',
#        'ENTIRE SCHEDULE CANCELLED LAST BROADCAST SATURDAY, APRIL 13, 1957',
#        'OVERLAY ITEM COULD NOT BE REMOVED WITHOUT DAMAGE TO THE ORIGINAL.',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION LOUISVILLE, KENTUCKY 40201',
#        'ADDENDUM I DAWSON RESEARCH CORPORATION Protocol Change Order No. 1',
#        'ELI CUTTER KS, for test market, using AMELIA "B" Blend (XLF -680G)',
#        'PRIMARY DISTRIBUTION CHANNEL (E. G. JOBBER, SUB- JOBBER MEMBERSHIP',
#        'SIX STAMFORD FORUM P. O. BOX 10380 STAMFORD CONNECTICUT 06904- 2380',
#        'Water removed by co- distillation with acetone under vacum at 45 C.',
#        '(Ladies & Men) . . . Friday, August 16, starting time is 3:00 P. M.',
#        'RSS RDC PHL PRC DRB Records Project Leader Other Personnel Assigned',
#        'PREDOMINANT BUYDOWN VALUE OF TARGETED BRANDS (DORAL G. P. C/ BASIC)',
#        'PLEASE NOTIFY THIS DEPARTMENT OF ANY CHANGES IN THE CODE NUMBER(S).',
#        'AAAS Meetings Office 1101 Vermont Ave., N W. Washington, D. C. 20005',
#        'Please complete the following If checked "NO" for corporation above:',
#        'Laborat. Radiobiology& Environmental Health - U. of Cal. San Francis',
#        'For personal injuries resulting after smoking "Pall Mall" and "Lucky',
#        'Research Group Manager Bonnie Fuller V. Hansberry (If International)',
#        'LOEWS/ LORILLARD PUBLIC AFFAIRS COMMITTEE CONTRIBUTION IDENTITY CARD',
#        '(Description of Location or Rotary Plan, Brand Category Competition)',
#        'B&W. ALL BIDS SHOULD BE BASED ON THE SPECIFICATIONS IN THIS DOCUMENT.',
#        'DIRECT ACCOUNTS PROJECTED TO ACCEPT WHICH REFUSED ONE OR MORE PACKING',
#        'MARDEN- KANE. INC. 666 FIFTH AVE. NEW YORK, N.Y. 10103 (212) 582-6600',
#        'Please indicate the capacity in which you are executing this document:',
#        '(Condition, Structures, Painting Ability, Lighting, Cooperation, etc.)',
#        'BRUSSELS CORRESPONDENT OFFICE 44 AVENUE DES ARTS BRUSSELS 1040 BELGIUM',
#        'reduction to the range of 8- 10mg tar. Variations to be: 1) Same taste',
#        'Borriston Laboratories, INC. , 5050 Beech Place Temple Hills, MD 20748',
#        'Acute Toxicity of Reference Cigarette Smoke lafter Inhalation in Mice.',
#        'Batten, Barton, Durstine & Osborn INCORPORATED CHANGE IN RADIO SCHEDULE',
#        'Sample No. 1078-84 Type of Cigarette NP Control 85 Batch Size As needed',
#        'All smokers will be 18 years and over and smoke 10+ cigarettes per day.',
#        '26 East 63rd Street, New York, N. Y. 10021 (Include state and zip code)',
#        'Moisture content of tar .48% as determined by near infrared spectroscopy',
#        "GEN'L ACCT DEPT. APTEKICKSER MURIEL, KAMNIT PRE MALARA (2) HOPE MARTINEZ",
#        'Bulk in cartons, FOB Oceanside Please allow 14 working days for delivery',
#        '1. Name, address and telephone number of law firm representing claimant:',
#        '"Effect of Nitrates in Tobacco on the Catechol Yield in Cigarette Smoke"',
#        '(1 COPY TO EACH) LAB ANIMAL MEDICINE QUALITY ASSURANCE CONTRACTS Sponsor',
#        '- Philip Morris- SPECIAL PROMOTIONS ON MAKLBORO AND CAMBRIDGE CIGARETTES',
#        'HAROLD WILLIAMS BROWN & WILLIAMSON TOBACCO CORPORATION LOUISVILLE, U.S.A',
#        'ABC+ who are not rejectors of imported cigarette and live in Seoul/ Pusan',
#        "characteristics as current True 100's product and, 2) Taste characterist-",
#        'DOCUMENT COPIES WERE REPRODUCED IN COLOR PERMIT CORRECTION INTERPRETATION',
#        'This Purchase order is to cover all costs incurred to- date listed below.',
#        'RESTRICTED BROWN & WILLIAMSON INTERNATIONAL TOBACCO PRODUCT SPECIFICATION',
#        '41 Kenosia Avenue, Danbury, CT 06810 Phone 203 794- 0323 Fax 203 748- 6304',
#        'DOCUMENT COPIES ARE IN THE SAME SEQUENCE AS THEY APPEARED IN THE ORIGINAL.',
#        '2525E Market Street, P.O. Box 21688, Greensboro, North Carolina 27420 1688',
#        'Return to J. R. Mueller no later than two weeks prior to anticipated trip.',
#        'J. F. Banks C. Lamb C. L. Domeck Webb L. C. Lanham Branch QC Branch Supply',
#        '250 Males, (100 smokers 25 ~ 29 years old, 150 smokers, 30 ~ 39 years old)',
#        'LASER PERFORATED TIPPING APPEARANCE CHECK HOLE DEPTH, SCORCHING, CRATERING',
#        'Director of Technical Operations, Brown & Williamson International Tobacco',
#        '37TH ANNUAL MEETING AUGUST 15-18, 1996 RYE- TOWN HILTON HOTEL RYE, NEW YORK',
#        'DESIGNATED SYSTEM OWNER BEFORE SUBMISSION TO THE MIS CLIENT SYSTEMS MANAGER.',
#        'Reference OR 100- 32 . 5g A30 soluble in .5 mL corn oil at room temperature.',
#        "may not be accurately predicted from survival after a single day's exposure.",
#        'IN TESTIMONY WHEREOF I have set my hand and seal the day and year aforesaid.',
#        'Current Kool Filter King Colombia 1 1 mg tar @ 0. 51% menthol white tipping.',
#        'DIR. OF LIFE SCIENCES HEALTH SERVICES COMPOUND PREP (TOX) SCIENTIFIC RES TOX',
#        'QUALITY IMPROVEMENT SUGGESTION OUR MISSION IS SUPERIOR CONSUMER SATISFACTION',
#        'ADDITIONAL SUPPLY WOULD BE HELPFUL. INITIAL QUANTITIES WERE QUICKLY DEPLETED',
#        'DIR OF LIFE SCIENCES HEALTH SERVICES COMPOUND PREP (TOX) SCIENTIFIC RES (TOX)',
#        'B164 forms a suspension in corn oil at 0.5g/ 1.5 ml Triple dosing is required',
#        'KS 1 mg grooved product using 4. 3/ 37 filter material. Cigarette code 244131',
#        '"Presenter/ Girl Rev" AT-M B-T-64 :60 "Pall Mall Filter Tip" AT-P/ F-T-317 :30',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION BID REQUEST FORM (QUALITATIVE RESEARCH)',
#        'Page 4 - Last line should be Mass spectrometric instead of Mass spectroscopic.',
#        'These costs will include but are not exclusive to the the following materials:',
#        'LAURENCE, CHARLES, FREE & LAWSON, INC. BULLETIN ADVERTISING- INSPECTION REPORT',
#        'Excellent movement when couponed. Without coupons, movement slows dramatically!',
#        'A pipe tobacco containing activated charcoal - must show vapor phase reduction.',
#        'Please place the following order for KOOL and/ or GPC Golf Bags for my Section:',
#        'Phyllis G. Jonnings, Asst. Socy,. The Corporation Company, Jacksonville, Florida',
#        'Current Marlboro Lights Menthol King US 9mg tar @ 0. 66% menthol, white tipping.',
#        'Boston Park Plaza Room 412 64 Arlington Street Boston, Mass 02117 617/ 426- 2000',
#        'Facsimile Transmission Legal Department 120 Park Avenue New York, NY 10017- 5592',
#        'To determine if the NSS concept/ product is viable based upon smokers reactions.',
#        'HAROLD WILLIAMS BROWN & WILLIAMSON TOBACCO CORPORATION LOUISVILLE, KENTUCKY U.S.A',
#        '(Ladies & Men) . . . Friday, August 16, Tee off at 8:00 A. M. SHARP (no green fee)',
#        'Current VICEROY 84 except with 25% of the propylene glycol replaced with SORBITOL.',
#        'D. WEST, L. GIORDANO, V. LINDSLEY, A. SADOVNICK S. RAPISARLDI B. DAVIN. A. Pasheluk',
#        'September 10, 1997 Marcus Hellenic Spirit Charities Golf Classic September 18, 1997',
#        'B. Enclosed is a check or money order in the amount of $ as a contribution to LOPAC.',
#        'CITY OF REIDSVILLE CHEMICAL MANAGEMENT PLAN 1993 INVENTORY CHEMICAL USAGE FACT SHEET',
#        'Section III A. 2nd paragraph- the first sentence is to be changed to read as follows:',
#        'Calculation of 1997 STR volumes for these brands for allocation of Period 2A budgets.',
#        'T. BAYLIES, L. GIORDANO V. LINDSLEY, J. SCHNEFF, S. RAPISARLDI, N, DISCENZA E LUNDBERG',
#        'Final approval is, of course, dependent upon time and placement of the commercial(s\uf703).',
#        'Average Coupon Buydown Value On Targeted Brands (Doral/ Basic/ Monarch/ Cambridge/ GPC',
#        'Research Design (N, Cells, Elegibility, Design, Key Banner Breaks, Methodology, Cities)',
#        '2. Cigts. to be inspected, placed in pk. mailers and shipped Inc., for Mkt. Rsh. Study.',
#        "2 Joe's Place Exhibits for use at Winston Cup, Winston Drag and Camel Super Bike Events.",
#        '"We really appreciate Lorillard thinking us." Shiffert\'s Wholesale, Visalia, California.',
#        'C T SYSTEM The Corporation Trust Company C T Corporation System and Associated Companies',
#        '1201 PENNSYLVANIA AVENUE N. W. P. O. BOX 7566 WASHINGTON D. C. 20044 7566 (202) 562 5000',
#        '408 Menthol Lights / 105 Menthol Ultra, 111 Non- Menthol Lights / 92 Non- Menthol Ultras)',
#        'BROWN & WILLIAMSON TOBACCO CORPORATION MATERIAL SPECIFICATION DESIGN CHANGE AUTHORIZATION',
#        'RESEARCH COMPLETED OR IN PROGRESS WHICH HAS POSSIBILITIES FOR PRESENTATION OR PUBLICATION',
#        '1099 name for number listed above proper name of egal as shown on IRS form (please print)',
#        'Sample repeated as RE- 341 because 2. 1/ 58 ,000 tow was used instead of 2. 1/ 42 ,000 tow.',
#        'The only other tobacco in the market was a standing 6 Panel RJR buy currently showing Camel.',
#        '101 N. CLASSEN BLVD. SUITE 102. OKLAHOMA CITY OK. 73118 TELEPHONE 405) 543- 0455 or 04600460',
#        '"Thank You very much for the tickets, we had a great time" Rogers Liquor, Marina California.',
#        '2. Names of first named plaintiff and first named defendant on the caption of the complaint:',
#        'Varies by market, see attached list. Approx. 20% of the total # by state will receive product',
#        'Make copies of this form if necessary. Complete applicable section (s) and return to NYSAWMD.',
#        'Address, postal requirements, barcodes, document storage, and batch numbers to be supplied by:',
#        'Further information (please attach any relevant materials; POS, advertising, brochures, etc.):',
#        'LIST THE INFORMATION BELOW AS IT PERTAINS TO THE URBAN CENTER PORTION OF YOUR ASSIGNMENT ONLY:',
#        '9143 PHILLIPS HWY. SUITE 120. JACKSONVILLE, FL 32256 TELEPHONE (904) 464 0800 FAX (904) 464 744',
#        'In order to establish a quantitative basis for determining the winning product, results will be',
#        'A 14 Day Repeated Dose Assay for Reference Cigarette Smoke in Mice (I- 1725.001- M1 is attached.',
#        'Have you paid any type of compensation or incurred any obligation for payment to the above named',
#        'Reuben Sunstein, Plaintiff, v. The American Tobacco Company, a New Jorsey corporation, Defendant.',
#        'Ms. Brock requested information regarding L&M lawsuit. I provided the approved prepared response.',
# ...
#        'For confirmation by the Committee. Check for $ 43, 910. 30 representing the ninth semi- annual installment to the Harvard Project transmitted August 1976.',
#        "1999 showed that imported cigarettes are recovering from the 1997 / 1998 economic crisis and we forecasted continuos growth over the company's plan period.",
#        'Strike" cigarettes manufactured by defendant, wherein plaintiff alleges breach of was- anties, seeks damages in excess of $5, 000 and demands trial by jury.',
#        '* A number of stores are part of an Arab owned collective that gets a large order delivered from a jobber and then distributes the cigarettes to each store.',
#        'HAS PROVEN TO BE AN EXCELLENT TOOL IN GENERATING PACK TRIAL IN BOTH HIGH AND LOW DEVELOPMENT PRICE VALUE MARKETS. MANY DISPLAYS SELLING OUT BEFORE RECONTACT.',
#        'PLEASE RETURN TWO (2) COPIES OF THE LOCATION LIST ALONG WITH TWO (2) COPIES OF THIS COMPLETION REPORT FORM TO THE ATTENTION OF MR. JOSEPH VAZQUEZ AT THE ABOVE ADDRESS',
#        'To develop cigarette Cigarette to utilize a filter tip with longitudinal grooves from the mouth end to the tobacco end in con- junction with perforated tipping paper.',
#        'To achieve growth we consider fundamental to have a superior product in terms of acceptability among potential source of business as well as for our current franchise',
#        'If any addresses or telephone numbers have changed since the last reporting period please check here and note the change in the space provided at the end of this form.',
#        'Lorillard Representative will supply all display materials and assemble display. Display containing deals will be placed on a self- service basis for a two- week period.',
#        "Reporter then requested clarification of generic cigarette vs. 'private label cigarette' and asked to be notified when further announcements regarding generics were made.",
#        'We hereby certify charges shown above on dates per attached bill are true and correct as billed to the account in upper right hand corner of the affidavit and are exclusive',
#        'Group 1= Best redeeming customers (2+ paid coupons): n= 750 Group 2= Paid redeoming customers 1 paid coupon) n= 750 Group 3= Non- redeeming customers (no redemption) n= 750',
#        'P. LORILLARD CO. , INC. RESEARCH DIVISION QUALITY CONTROL DEPARTMENT SMOKE ANALYSIS AND BURNING TEST REPORT WEEKLY PRODUCTION LITTLE CIGARS NON FILTERS WEEK ENDING 11/ 25 /66',
#        'yes, please detail. including the names of the persons receiving and in whose behalf such expenditures have been made, the amount, date, place, and reason for the expenditure.',
#        'M. Lymph: negative with S9 activation, positive without S9 activation; Rerun: negative without S9 activation, border- line positive with S9 activation -Technical problems with the',
#        'The change was made so the protocol more closely conforms with the proposed regulations as stated in the Federal Register, Vol. 44, No. 145, 772.112-24 Primary Eye Irritation Study.',
#        'Tested among a half sample of smokers. Sub- group scores subject to wide variation because of small sample size and should be averaged across several ads for meaningful infor- mation.',
#        'Perhaps the tickets could be sent but a little sooner This year the tickets arrived on Thursday and the race was Sunday. This made it difficult to get the tickets to customers on tine.',
#        'of respiratory depression, constriction of blood vessels, and in- activity. Survivors recovered in 48 hours. The recommended safe dose for a single trial by inhalation in man is 0.3 mg.',
#        'SPECIFICATIONS ON ROLLS 34 & 35. WT. AV. ROLL 34 (183. 04) ; WT. AV. ROLL 35 (183. 44) : SPECS. 190 -210 GMS/ SQM. LOI OUT DE SPEC. ON ROLL 34 (AV 2. 49%) SPECIFICATIONS (2.6 6- 3. 1% .',
#        'A. I hereby authorize, until further notice, a voluntary contribution by salary deduction to the Loews/ Lorillard Public Affairs Committee (LOPAC) of the following amount per pay period:',
#        'If you have received this communication in error, please immediately notify us by telephone, and return the original message to us at the above address via the U. S. Postal Service. Thank you.',
#        'Acute Cardiovascular- Mix 2 mg A32 with 0.2 ml 80% propylene glycol and grind lightly. Add 0.8 ml saline solution. A32 is a suspension in this mixture at room temperature. Reference OR 72- 152.',
#        '5. Specify the nature or type of asbestos- related injury alleged by the claimant. (E. q., Asbestosis; Lung Cancer- adenocarcinoma Lung Cancer- Mesothelioma; Pleural Thickening; Fibrosis; etc.)',
#        'DO NOT MAKE ANY COMMITMENT OR AUTHORIZE ANY EXPENDITURE OF ANY KIND FOR ACCOUNT OF THIS COMPANY UNTIL EXECUTIVE APPROVAL HAS BEEN OBTAINED HEREON (BE GUIDED BY PPM 60,020 IN COMPLETING THIS FORM)',
#        'Delete coal retention from the list of standard analyses performed on licensee submitted product samples. Special requests for coal retention testing could still be submitted on an exception basis.',
#        'The pH of a 50% concentration of B164 in water was calculated to be 4.82 at 25°C according to the extrapolation procedures by Dr. P. D. Schickedantz, Lorillard Research Center Accession Number 1662.',
#        'The plant is well maintained and covers all parts of the market. Lamar looks like a good citizen here, keeping a good- looking public and carrying lot operation. doing service, a of local advertisers.',
#        'By the way, we received 13 more signature cards today and sent the cigarettes out. We are now up to 74 respondents who have been sent cigarettes. Hopefully we will get a lot of callbacks this weekend.',
#        "On September 1 97, PMI simultaneously launched Marlboro Menthol KS Box (16mg tar and Menthol Lights KS Box (9mg tar) in Colombia. These two products became KOOL's direct competitors (Premium Menthol Brands).",
#        'Send this registration form, along with payment to address noted below in attached envelope. Enclose a cheque or international money order payable in Canadian funds to the 46th Tobacco Chemists Research Conference.',
#        'difficult to locate. Also, the Indy Lights Paddock area was not clearly identified Most Invitees were looking for the hospitality tent in a separate identified area away from the Paddock Brea and the Newport car transporter.',
#        'The pH of a 50 % concentration of A30 in (52.6% dioxane/ water was calculated to be 8.13 at 24 C according to the extrapolation procedures by Dr. P. D. Schickedantz, Lorillard Research Center Accession Number 1662, Reference OR 83- 81.',
#        'REVISED COST DUE TO A QUESTION ADDED TO THE SECOND WAVE AND CHANGES MADE IN WORDING OF OTHER QUESTIONS. THIS COVERS THE COST OF ADDITIONAL TELEPHONE INTERVIEW LENGTH, CODING OF THE OPEN- END, PROGRAMING CHANGES, TABULATION AND ANALYSIS.',
#        'Client confirmed agreement for Agency to pay advance to with official photographer, signed estimate to follow, for 1/ 25/ 82. This was Viceroy Shoot week of agreed to by T. and January Parrack A. 18 pre- Forsythe production at the meeting',
#        'A11 parts of the pathology phase of this study, including the final report, were reviewed by Experimental Pathology Laboratories Quality Assurance Unit on March 2- June 8, 1983 . All Findings were reported to the Study Director and Management.',
#        'Here is yet another version of the questionnaire. Please note that the last 2 pages are at the alternate versions that we discussed. Take a look at the alternate Q9 to try to get at the intensity issue, and maybe we can improve on it from here.',
#        'pH- The pH of a 50% concentration of A32 in a 52.6% dioxane/water solution was calculated to be 2.92 at 22°C according to the extra- polation procedures by Dr. P. D. Schickedantz, Lorillard Research Center Accession No. 1662, Reference OR 83- 125.',
#        'THIS WILL CERTIFY THAT I HAVE EXAMINED THE RECORDS OF OUR BILLPOSTERS, AND VERIFY THAT ALL LOCATIONS LISTED ON THE ATTACHED LOCATION LIST WERE PROPERLY POSTED WITH THE CORRECT DESIGN WITHIN FIVE WORKING DAYS OF THE POSTING DATE ACCEPTED ON THE CONTRACT',
#        "III. SUPPLEMENTAL LITERATURE SEARCH Chemical Abstracts Vol. 23 - Vol. 65 Arctander' s Perfume and Flavor Materials of Natural Origin (1960) Guenther' s Monographs on Fragrance Raw Materials (1979) Tobacco Abstracts U. S. Dispensatory 23rd edition (1943)",
#        'Develop 14- mg "tar" delivery king size cigarette for generic pricing directed toward young male smokers. Cigarette dimensions- 85 mm x 24.9 mm circumference- 20 mm filter- 24 mm tipping. Offshore tobacco blend with unique flavor formulation. Cork tipping.',
#        'During this reporting period, have you made any expenditure or incurred any obligation of $ 25.00 or more per occurence to promote or oppose any legislation, including but not limited mailings, meals, print or broadcast advertisements, or gifts (yes or no)',
#        'Spray 50 lbs. tobacco with solution of 880 g (= 1. 94 lbs.) PMC in 1175 ml of denatured alcohol. This should give 3. 4% PMO add- on (3. 3% PMO contained) assuming 88% spraying efficiency. PMO delivery from 85 mm cigarette smoked to 30 mm butt should be 6. 5 mg/ cig.',
#        'This bill regulates smoking in university buildings which house educational programs and in inpatient health care facilities. Smoking within these or rooms, provided buildings would be allowed only specified facilities designate these "smoking permitted" areas. that signs are posted to',
#        'This is a comparatively easy market to cover. It is less than an hour from Tampa airport. Our bulletins are on every major arterial and in all No quadrants of the area. changes were made. Some minor on- premise blocking and trees were noted, but deemed serious enough for correction. not',
#        'NOTE- Execute in triplicate using additionall sheets if more space is required. Retain the third copy for your file Return the original (signed) and the first carbon (unsigned) along with the manuscript to this office The unsigned copy and the manuscript will be for returned to the author his consideration.',
#        '(See SOP for Determination of Solubility of Materials for Acute Cardiovascular and Respiratory Effects Study in Beagle Dogs) Reference OR 100- 32 .2 mg A30 soluble in .5 mL 10 % propylene glycol solution at 38 C. Add A30 to warm (38 C) propylene glycol; add warm water to make 10 % propylene glycol solution.',
#        'Posters are captioned for identification, "LUCKY STRIKES AGAIN (printed in red) with the word "New" printed in a snipe effect in the upper left corner. These posters have a white background and will be further identified as such in order to differentiate from a second design which will have a solid red background with white lettering.',
#        'Material # 50 -034 A has been assigned to the VICEROY Rich Lights 100\' s 20\' s Label with new bottom panel. Bottom now incorporates shield. On both side and bottom panels, "VICEROY" and "Rich Lights" have been inverted. Cartons and labels must change design simultaneously. The current design cannot be used in production after 10/ 30/ 81.',
#        'The current system of managing records is too complex. The trend seems to be increasingly specific, when we should be getting more general. Right now, people must work to understand the system. We must spend too much time adninistering the system, labeling and cleaning our files. Complying is a real burden, both for the individual and for the records coordinators.',
#        'Discontinue coal retention analyses on licensee submitted product samples (Note : Coal Retention testing is not performed by most licensees. Other B&W physical measurements as ends stability and inspection for soft spots in ciparettes are thought to be sufficient measures to assure cigarette physical integrity. The proposed action will increase laboratory productivity . )',
#        'This is your authorization to perform the "Acute Oral Toxicity Study in the Rat" tests on materials D13 and D23 supplied by Lorillard. The fixed price for each test is $2050 for each material, for a total price of $4100. Studies are to be conducted in accordance with the October 17, 1980 formal agreement between Borriston and Lorillard. All work is to be coordinated with our Dr. Connie Stone (919) 373- 6663.',
#        'The information contained in this facsimile message is attorncy privileged and confidential information intended only for the use of the individual or entity named above. If the reader of this message is not the intended recipient, or the employee or agent responsible to deliver it to the intended recipient, you are hereby notified that any dissemination, distribution or copying this communication strictly prohibited.',
#        'Now you can win up $ 5,000 for simply picking the winners of the games listed below. Just check the box next to the team you think will win. Allow for the point spread in your selections. (For example, if a team is quoted as +7 pts. this means they must win the game by at least 7 points.) Prizes will be awarded by random drawings to those who have the greatest official number of winning selections. Full details are in the Rules.',
#        'THIS FACSIMILE TRANSMISSION IS INTENDED ONLY FOR THE ADDRESSEE SHOWN BELOW. IT MAY CONTAIN INFORMATION THAT IS PRIVILEGED, CONFIDENTIAL OR OTHER WISE PROTECTED FROM DISCLOSURE. ANY REVIEW, DISSEMINATION OR USE OF THIS TRANSMISSION OR ITS CONTENTS BY PERSONS OTHER THAN THE ADDRESSEE IS STRICTLY PROHIBITED. OF YOU HAVE RECEIVED THIS TRANSMISSION IN ERROR, PLEASE NOTIFY IMMEDIATELY BY TRIEPHONE AND MAIL THE ORIGINAL TO US AT THE ABOVE ADDRESS.',
#        'This is your authorization to provide the "1601.013: The Effect of Inhalation of Reference and Test (D3 and D4) Cigarette Smoke on Two Cytogenetic Endpoints in Mice: Chromosome Aberrations and Sister Chromatid Exchange" test for a fixed price of $19,750 Tests will be performed in accordance with the December 21, 1981 formal agreement between Microbiological Associates and Lorillard. All work is to be coordinated with our Dr. Harry Minnemeyer (919) 373-6603',
#        'university buildings would each It is estimated that, on the average, The per "smoking signs. sign cost is require about three permitted" This estimate is based on the estimated at $4 50 in 1982-83 dollars. 1981 increased to reflect Inflation from 1981 to 1983. per sign cost, and Thus, the expected one-time cost for the University Systet to implement no be about There are significant the provisions of the bill would $8,000. with the bill\'s provisions. continuing annual costs associated',
#        'My contribution is voluntary. I am aware of my right to refuse to contribute without reprisal of any kind.  I am aware of the politicial purpose of LOPAC. I am aware that a copy of the report of LOPAC is filed with the Federal Election Commission and is available for purchase. I am aware that the guidelines above as to the amount of my contribution are only suggestions. I am aware that my contribution counts against my individual contribution limit. I am an American citizen or I have been admitted to permanent U. S. residence.',
#        'The Cigarette Test Station (CTS400) combines many of the stand- alone instruments that R&D currently uses to measure cigarette weight, pressure drop, ventilation, and hardness into one compact module. The CTS400 has the additional measurement of cigarette hardness in comparison with the CTS300. With this added, measurement R&D will be able to replace the Firmness Integrator that measures cigarette firmness in addition to other measurements that are mentioned above. The Firmness Integrator is no longer manufactured and parts are becoming difficult to obtain. Lastly, purchase of this instrument would provide similar capability as the Macon Plant and help facilitate comparisions between laboratories.'],
#       dtype=object)

# %%
data.loc[index].tail(30)['label'].value_counts()
# Out:
# answer      19
# other        9
# question     2
# Name: label, dtype: int64

# %%
data.loc[index].tail(530)[data.loc[index].tail(530)['label']=='question'].text.values
# Out:
# array(['Registry of the Toxic Effects of Chemicals',
#        'Decision of Committee on Present Request -',
#        'Total number of pages including this page:',
#        'Increase Costs - May Be Possible to Absorb',
#        'TOTAL REPORTABLE EXPENDITURES FOR VARIETYI:',
#        'FOLLOW DEPARTMENT AND COMPANY SAFETY MANUALS',
#        'FOLLOW DEPARTMENT AND COMPANY SAFETY MANUALS',
#        'NG DOCUMENTS WERE FOUND WITHIN THE ORIGINAL:',
#        'PAGE NUMBER(S) WERE MISSING IN THE ORIGINAL.',
#        'Date of Final Report (Review Completed Date)',
#        '% OF DISTRIBUTION ACHIEVED IN RETAIL OUTLETS:',
#        'Reimbursements for expenses (please itemize):',
#        'who being duly sworn, says that (he) (she) is',
#        'Source of Business - Local Premium KS Smokers',
#        '% OF DISTRIBUTION ACHIEVED IN RETAIL OUTLETS:',
#        'CONTROL REVERTANTS PER PLATE TOON MI SOLVENTI',
#        'Application: tipping, carton end flaps, etc.)',
#        'NAMES OF OTHER PERSONS COLLABORATING IN WORK:',
#        'CONTROL AFVERTANTS PER PLATE (0.05 ml SOLVENT)',
#        'Advance Registration Fee: (prior to August 10)',
#        'APPLICATION (Circle One and Briefly Describe):',
#        'Sign & Print Names) (See Instructions On Back)',
#        'INBIFO Institut für biologische Forschung GmbH',
#        'Recommended Brand(s) and Promotional Activity:',
#        'Information and hearsay from outside contacts:',
#        'Before me a Notary Public, personally appeared',
#        'Asumptions Used in Arriving at Fiscal Estimate',
#        'TOTAL # OF INDEPENDENT NEWPORT #1 CLUB OUTLETS:',
#        '(26) TOTAL REPORTABLE EXPENDITURES FOR VARIETY:',
#        'APPROXIMATE % OF RETAIL CALLS SECURED BY GLASS:',
#        'The following document, including cover page is',
#        'TOTAL # OF INDEPENDENT SPECIAL EMPHASIS OUTLETS:',
#        'If there is a transmission problem, please call:',
#        'TOTAL # OF SP EMPHASIS OUTLEIS WITH DISTRIBUTION',
#        'SUGGESTION: (Describe Current Situation and Idea)',
#        'Amendment (Attach additional sheets as necessary)',
#        'Company Improvements & Administrative Requirements',
#        'Name of spouse participating in the guest programs',
#        'IF YOU DO NOT RECEIVE ANY OF THE PAGES, PLEASE CALL',
#        'Part of Final Report to be Amended (Exact location)',
#        'TOTAL # OF NUMBER ONE CLUB OUTLETS WITH DISTRIBUTION',
#        'RINCIPAL ORGANIZER (who will receive correspondence):',
#        'Please make the necessary Field Trip arrangements for',
#        '(ONLY PARTIAL REGION CONTINUE WITH DIVISION(S) SCOPE)',
#        'Arrival date and time (include airline and flight no.)',
#        'AT (919) AT THE GREENSBORO BRANCH AS SOON AS POSSIBLE.',
#        'REVISIONS TO SHELL (Other than Term Compensation or Job',
#        'to be performed in Acute /Dermal Toxicology, building 18.',
#        'NYSAWMD, INC. 211 EAST 43RD STREET, NEW YORK, NY 10017-4707',
#        'Any special dietary meal and/ you or your guest would prefer',
#        'Following physical/ visual properties out of specifications:',
#        'REVERSION RATE (TEST REVERSANTS/CONTROL REVERTANTS PER PLATE',
#        'REVERSION RATE TEST REVERTANTS-CONTROL REVERTANTS PER PLATE)',
#        'SUBJECT TO THE FOLLOWING SUGGESTED REVISIONS: (itemize below):',
#        'ESTIMATE OF TIME NEEDED TO PREPARE MANUSCRIPT FOR PUBLICATION:',
#        'IF YOU HAVE ANY QUESTIONS, PLEASE CONTACT THE FOLLOWING PERSON:',
#        'IF YOU HAVE ANY QUESTIONS, PLEASE CONTACT THE FOLLOWING PERSON:',
#        'ESTIMATE OF TIME NEEDED TO PREPARE MANUSCRIPT FOR PRESENTATION:',
#        'Do you prefer airline seats in smoking or non- smoking section:',
#        'AT THE TIME OF REPRODUCTION, THE FOLLOWING NOTATTONS WERE MADE:',
#        'PRESENT STATUS OF WORK (Cite progress reports where appropriate)',
#        'PRIMARY DISTRIBUTION CHANNEL (E. G. JOBBER, SUB- JOBBER MEMBERSHIP',
#        'PREDOMINANT BUYDOWN VALUE OF TARGETED BRANDS (DORAL G. P. C/ BASIC)',
#        'PLEASE NOTIFY THIS DEPARTMENT OF ANY CHANGES IN THE CODE NUMBER(S).',
#        'Please complete the following If checked "NO" for corporation above:',
#        'Please indicate the capacity in which you are executing this document:',
#        'IN TESTIMONY WHEREOF I have set my hand and seal the day and year aforesaid.',
#        'DIR. OF LIFE SCIENCES HEALTH SERVICES COMPOUND PREP (TOX) SCIENTIFIC RES TOX',
#        'These costs will include but are not exclusive to the the following materials:',
#        'Please place the following order for KOOL and/ or GPC Golf Bags for my Section:',
#        'Section III A. 2nd paragraph- the first sentence is to be changed to read as follows:',
#        'Final approval is, of course, dependent upon time and placement of the commercial(s\uf703).',
#        'Research Design (N, Cells, Elegibility, Design, Key Banner Breaks, Methodology, Cities)',
#        'Address, postal requirements, barcodes, document storage, and batch numbers to be supplied by:',
#        'Further information (please attach any relevant materials; POS, advertising, brochures, etc.):',
#        'LIST THE INFORMATION BELOW AS IT PERTAINS TO THE URBAN CENTER PORTION OF YOUR ASSIGNMENT ONLY:',
#        'Have you paid any type of compensation or incurred any obligation for payment to the above named',
#        'Enclosed are copies of legal proces served upon the statutory agent of the above company as follows:',
#        'Check columns below only if bill makes a rect appropriation or affect a sum sufficient appropriation.',
#        'I will participate in the Tennis Tournament I would classify myself as (please check appropriate box)',
#        "Due the 1st Monday of the month during the legislative session to report the previous months' activity.",
#        'Describe the storyline, list the questions and proposed answers, and summarize handling, including clearances.',
#        'of the abovementioned newspaper and that display ads for the above account were made through the aforesaid newspaper during',
#        'To cover the cost of collateral merchandising materials to be used in 1991 in connection with the merchandising and promotion of BULL DURHAM.',
#        'If any addresses or telephone numbers have changed since the last reporting period please check here and note the change in the space provided at the end of this form.',
#        'We hereby certify charges shown above on dates per attached bill are true and correct as billed to the account in upper right hand corner of the affidavit and are exclusive',
#        'yes, please detail. including the names of the persons receiving and in whose behalf such expenditures have been made, the amount, date, place, and reason for the expenditure.',
#        '5. Specify the nature or type of asbestos- related injury alleged by the claimant. (E. q., Asbestosis; Lung Cancer- adenocarcinoma Lung Cancer- Mesothelioma; Pleural Thickening; Fibrosis; etc.)',
#        "III. SUPPLEMENTAL LITERATURE SEARCH Chemical Abstracts Vol. 23 - Vol. 65 Arctander' s Perfume and Flavor Materials of Natural Origin (1960) Guenther' s Monographs on Fragrance Raw Materials (1979) Tobacco Abstracts U. S. Dispensatory 23rd edition (1943)",
#        'During this reporting period, have you made any expenditure or incurred any obligation of $ 25.00 or more per occurence to promote or oppose any legislation, including but not limited mailings, meals, print or broadcast advertisements, or gifts (yes or no)'],
#       dtype=object)

# %% [markdown]
# We may have to use proper NLP model
